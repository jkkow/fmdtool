# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from mtool import LPModes
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\jkkow\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:3433 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In [1], line 3
#     from mtool import LPModes
#
#   File c:\Users\jkkow\repoz\fmdtool\mode_analysis\mtool.py:58
#
#     ^
# IndentationError: expected an indented block after 'if' statement on line 56
